# %% [markdown]
# # LinkedIn Data Science Jobs 2024 Canada dataset MEMO & REPORT

# %% [markdown]
# Markus Lähde 2024.02.26

# %% [markdown]
# # 1. DATA

# %% [markdown]
# #### Source:
#
# https://www.kaggle.com/datasets/kanchana1990/linkedin-canada-data-science-jobs-2024
#
# #### Data:
#
# linkedin_canada.csv

# %% [markdown]
# # 1.1 DATA: ORIGINAL FEATURES

# %% [markdown]
# ### COLUMNS
# ![image.png](attachment:ae3ce7f8-bbbe-4a22-b2b2-78cc5c3b598d.png)

# %% [markdown]
# ### NULL-VALUES
# ![image.png](attachment:979c19a3-df46-4f5f-b216-4b98a0680211.png)

# %% [markdown]
# # 1.2 DATA: DICTIONARY

# %% [markdown]
# #### Column Descriptors:
# The dataset contains the following key columns:
#
# -Company Name: The name of the company posting the job. : The title of the job posting. <br>
#
# -Location: Geographical location of the job. <br>
#
# -Contract Type: Type of employment contract offered (e.g., Full-time, Part-time). <br>
#
# -Experience Level: Required experience level for the job (e.g., Entry-level, Mid-Senior level). <br>
#
# -Sector: Industry sector of the job posting. <br>
#
# -Description: Brief description of the job role and responsibilities. <br>
#
# -Applications Count: Number of applicants for the job. <br>
#
# -At: The date when the job was posted

# %% [markdown]
# # 2. INITIAL EXPLORATION: NOTES

# %% [markdown]
# ### 'location' COLUMN
# ![image.png](attachment:55dc7cff-665f-4f2e-ac74-52620f0197ee.png)

# %% [markdown]
# # 'workType' COLUMN
# ![image.png](attachment:207ff59c-fa43-49bd-8b93-3b8121c09c9f.png)

# %% [markdown]
# ### NOTES ON DATASET:
# - 'applicationsCount' -> drop 'Be among the first 25 applicants', parse to int for analysis, create subgroups <br>
# - 'companyId' is meaningless feature for analysis -> drop <br>
# - 'contractType' has few null-values, dropping them would not affect analysis -> drop null rows <br>
# - 'description' could be parsed to try to identify meaningful keywords <- too much work for this report <br>
# - 'experienceLevel' -> ok <br>
# - 'location' is unfortunately useless, because so big portion of job postings don't have more specific location -> drop <br>
# - 'postedTime' is quite useless for this analysis -> drop <br>
# - 'publishedAt' is quite useless for this analysis -> drop <br>
# - 'salary' is practically meaningless feature as there are only 13/275 non-null values -> drop <br>
# - 'sector' is very interesting, null-values 11/275 could be dropped without much loss, maybe some parsing could be done <br>
# - 'title' is very interesting, experience levels (Junior, Senior...) could be parsed to new column as well as other values <br>
# - 'workType' has so poor distribution it's basically useless -> drop

# %% [markdown]
# # 2.1 ADDITIONAL MODIFICATIONS: applicationsCount

# %% [markdown]
# ### CREATING SUBGROUPS
# ![image.png](attachment:46bae564-8099-42ff-8c37-7812f0e0f66c.png)

# %% [markdown]
# # 2.2 ADDITIONAL MODIFICATIONS: sector

# %% [markdown]
# ### ORIGINAL UNIQUE VALUES
# ![image.png](attachment:386ef6e6-3120-4e93-8c40-1e56bceff22f.png)

# %% [markdown]
# # sector AFTER TRUNCATING VALUES TOGETHER
# ![image.png](attachment:e5ab2137-b489-4d8d-945e-2c01d1a62c34.png)

# %% [markdown]
# # 2.3 ADDITIONAL MODIFICATIONS: title

# %% [markdown]
# #### COLUMN title WAS MODIFIED BY REPLACING ORIGINAL VALUE BY ONE OF MOST PREVALENT VALUES FOUND IN CELLS
# -'machine_learning' <br>
# -'software_engineer' <br>
# -'software_developer' <br>
# -'data_scientist' (includes: 'data_science') <br>
# -'full_stack'

# %% [markdown]
# ![image.png](attachment:0bb950fc-575b-4cad-9360-5f2977ea7432.png)

# %% [markdown]
# # 3.0 MAIN RESULTS

# %% [markdown]
# ### JOB POSTINGS BY SECTOR
#
# ![image.png](attachment:74677c9b-06b8-4be2-ac28-f98c25c951d4.png)

# %% [markdown]
# ### ENTRY LEVEL JOB POSTINGS BY SECTOR
# ![image.png](attachment:d1268c31-5bb6-468a-b294-1c93c384eb35.png)

# %% [markdown]
# ## APPLICATION NUMBERS

# %% [markdown]
# ### IT Services/IT Consulting AND Software Development had mostly over 200 applicants per job posting

# %% [markdown]
# ![image.png](attachment:f93feb6e-61aa-4cd2-9132-4ea5fda5c255.png)

# %% [markdown]
# ![image.png](attachment:d94ceb76-7ee1-4815-8542-bfb7705e8b60.png)

# %% [markdown]
# ### Technology/Information/Internet AND Human Resources had more even distribution of applicants

# %% [markdown]
# ![image.png](attachment:0138a8ca-ba50-4d70-8566-acd1a4ab0527.png)

# %% [markdown]
# ![image.png](attachment:75eb912e-ea3d-4a44-8dbd-2764004ac7be.png)

# %% [markdown]
# ### Job postings with less applicants were on Financial Services

# %% [markdown]
# ![image.png](attachment:4086b369-52fb-4665-aa8b-08457cf9990d.png)

# %% [markdown]
# # TITLES

# %% [markdown]
# ### SECTORS WITH PREDOMINANTLY MACHINE LEARNING / DATA SCIENCE ORIENTED JOB TITLES

# %% [markdown]
# ![image.png](attachment:13fed5dd-a087-4452-885f-3146c265cf6a.png)

# %% [markdown]
# ![image.png](attachment:abcdb7fb-a108-4e57-8191-29e2126e43e9.png)

# %% [markdown]
# ![image.png](attachment:f699f746-a176-4720-ae5f-b038d4e048af.png)

# %% [markdown]
# ### SECTORS WITH PREDOMINANTLY SOFTWARE DEVELOMENT / ENGINEERING / FULL STACK ORIENTED JOB TITLES

# %% [markdown]
# ![image.png](attachment:42cf5883-298e-4300-a1a0-6e9b91e30e29.png)

# %% [markdown]
# # ENTRY LEVEL JOB TITLES WITH LESS THAN 50 APPLICANTS

# %% [markdown]
# ![image.png](attachment:253ec8eb-7ac8-4fd0-8b3c-ee16068353a3.png)

# %% [markdown]
# ![image.png](attachment:aa6e584d-825a-4abe-967f-5eab499cb73d.png)

# %% [markdown]
# # NOTES ON ANALYSIS

# %% [markdown]
# #### Yielding useful information from this dataset is hard without proper business problem.
# #### Even features that are easy to distinct (such as titles as they are used here) deliver very limited number of results.
# #### Scope of the original dataset could be bigger to include general software development postings.
# #### This would lead to more data with better opportunities to check for example prevalence of certain technologies in job openings.
